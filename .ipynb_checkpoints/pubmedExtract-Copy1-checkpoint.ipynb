# %% [markdown]
# ### Pubmed Extract
# Libraries:
# **Bio:** Biopython to use *NCBI's Entrez* utilities and get PubMed information
# **OS** use python miscellaneous operating system interfaces, use here to get the working directory
# **Randinit** generate random number
# **time** sleep functions - when you want to pause between requests (random number for the time)
# **Collections** defaultdict for dealing with missing keys

# %%
import os
# re module to write regular expressions - used to pull out doi's from string
import re
# import random number generator
from random import randint
# import to setup sleep and pauses
import time
# importing "collections" for defaultdict
# deal with missing keys in data dictionary of fetched records
import collections
from collections import defaultdict
# Biopython for NCBI's Entrez utilities
from Bio import Entrez
from Bio import SeqIO
from Bio import Medline
#from Bio import Medline
# use return type of MEDLINE
from Bio.Alphabet import IUPAC
Entrez.email = 'jamison@library.ucla.edu'
#  base url for PUBMED converter API
converterBase = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/"
#crossref api
from crossref.restful import Works

# %%
# esearch:  searches and retrieves primary ID's used in efetch, elink and esummary
# efetch retrieves records in the requested format from list of primary IDs

# %%
# uses python os module
# tells you where your default working directory is - ie. where files will be written
os.getcwd()
# Out:
# '/home/jmjamison/work/pubmedExtracts'

# %%
query='("University of California, Los Angeles"[Affiliation] OR "University of California, Los Angeles"[Affiliation] OR "University of California Los Angeles"[Affiliation] OR "University of California at Los Angeles"[Affiliation] OR "University of California of Los Angeles"[Affiliation] OR "University of California in Los Angeles"[Affiliation] OR UCLA[Affiliation] OR 90095[Affiliation]) AND ("2014/01/01"[PDAT] : "2018/01/31"[PDAT])'
handle=Entrez.esearch(db="pubmed", term=query)

# %% [markdown]
# #### Entrez esearch, read the results

# %%
handle = Entrez.esearch(db="pubmed", term=query)
record=Entrez.read(handle)
record["IdList"]
# Out:
# ['29686938', '29686739', '29686725', '29682398', '29682382', '29681647', '29676225', '29673526', '29672601', '29671273', '29671268', '29671267', '29671266', '29671265', '29671264', '29670931', '29670925', '29670334', '29666723', '29664956']

# %% [markdown]
# #### get the total number of records, print out, list out the pubmed records without specifying maximum records

# %%
record["Count"]
recordCount = record["Count"]
print(recordCount)
# Out:
# 21640

# %% [markdown]
# #### same but specify the maximum records, but  get same total number of records.

# %%
handle=Entrez.esearch(db="pubmed", term=query, retmax=recordCount)
result=Entrez.read(handle)
record["Count"]
recordCount = record["Count"]
print(recordCount)
# Out:
# 21640

# %% [markdown]
# #### print out a list of the Pubmed record numbers

# %%
# f = open('/home/jmjamison/work/pubmedExtracts/outputList.txt', "w")
# comment out so this will default to the default working directory
# 
# write out the id list - result
f = open('outputList.txt', "w")
f.write(str(result))
f.close()

# %%
handle=Entrez.efetch(db="pubmed", id=17383002, retmode="xml")
record=Entrez.read(handle)
# print(record) comment out print statement

# %% [markdown]
# #### search, read and fetch records, pull selected PubMed fields.

# %%
#fetchHandle=Entrez.efetch(db="pubmed", id=17383002, retmode="xml")
infoHandle = Entrez.einfo()
record = Entrez.read(infoHandle)
infoHandle.close()
print(record.keys())
record['DbList']

infoHandle = Entrez.einfo(db="pubmed")
record = Entrez.read(infoHandle)
record["DbInfo"]["Description"]
record["DbInfo"]["Count"]
record["DbInfo"].keys()
# Out:
# dict_keys(['DbList'])
# dict_keys(['DbName', 'MenuName', 'Description', 'DbBuild', 'Count', 'LastUpdate', 'FieldList', 'LinkList'])

# %%
handle=Entrez.esearch(db="pubmed", term=query, retmax=recordCount)
record=Entrez.read(handle)
record["Count"]
# Out:
# '21640'

# %% [markdown]
# Crossref rest api
# "singletons" - Singletons are single results. Retrieving metadata for a specific identifier (e.g. DOI, ISSN, funder_identifier) typically returns in a singleton result.

# %%
handle = Entrez.esearch(db="pubmed", term=query)
record=Entrez.read(handle)
idList = record["IdList"]
print(idList)
handle = Entrez.efetch(db="pubmed", id=idList, rettype="medline", retmode="json")
records = Medline.parse(handle)
Entrez.email = 'jamison@library.ucla.edu'
# declaring defaultdict
# sets default value 'Key Not found' to absent keys
#records = collections.defaultdict(lambda : 'Key Not found')
# How does it work? Simple. You can do one of two things to get directed to the "polite pool":
# Include a "mailto" parameter in your query. For example:

works=Works()
for record in records:
    # print(record["PMID"])
    PMID = record["PMID"]
    print(PMID) 
    # print(record["PMC"])
    # PMC = record["PMC"]
    # print(PMC) 
    # print("DOI: ID Converter API")
    # getDOI = converterBase + "?tool=my_tool&email=jamison@library.ucla.edu&ids=" + PMID + "&format=json"
    print(getDOI)
    print("Pubmed Record ID (PMID): " + record.get('PMID', ""))
    # print(record["TI"])
    print("Title: " + record.get('TI', ""))
    # print(record["AUID"])
    print("Author Identifier (AUID): " + str(record.get('AUID', "")))
    # print(record["AU"])
    print("Author(s)(AU): " + str(record.get('AU', "")) )   
    # print(record["AID"])
    print("Author affiliation (AD): " + str(record.get('AD', "")))  
    # print(record["AD"])
    # affiliation
    print("Article Identifier/DOI (AID): " + str(record.get('AID', "")))
    # print(record["GR"])
    # grant number
    print(record.get('GR', ""))      
    print("\n")

# %%
# f = open('/home/jmjamison/work/pubmedExtracts/outputIdListFull.txt', "w")
# comment out so this will default to the default working directory# 
# write out the id list - result
f = open('outputIdListFull.txt', "w")
# first esearch and then efetch
handle=Entrez.esearch(db="pubmed", term=query)
# read - sould now be a Python dictionary/list
searchResult=Entrez.read(handle)
handle.close()
idList=searchResult["IdList"]
ids= ','.join(idList)
listCount=searchResult["Count"]# now have a list of record ids
#print(idList)
#print(ids)
#print(searchResult)
f.write(str(searchResult["IdList"]))
# now have a list of record ids
print(idList)
print(ids)
#print(searchResult)
f.close()

# %%
from random import randint
import time
# f = open('/home/jmjamison/work/pubmedExtracts/outputPubMed.txt', "w")
# comment out so this will default to the default working directory# 
# write out the id list - result
f = open('outputPubMed.csv', "w")
# first esearch and then efetch
searchHandle=Entrez.esearch(db="pubmed", term=query, retmax=recordCount)
# read - sould now be a Python dictionary/list
idList=searchResult["IdList"]
ids= ','.join(idList)
searchResult=Entrez.read(searchHandle)
fetchHandle = Entrez.efetch(db="pubmed", id=ids, rettype="medline", retmode="text")
handle.close()

listCount=searchResult["Count"]
print(listCount)
# now have a list of record ids
#print(idList)
#print(ids)
#print(searchResult)
records = Medline.parse(fetchHandle)
print("Total records: " + listCount)
f.write("Pubmed Record*Title*AUID-Author Id*AU-Author*AD-Affiliation*AID-Article Id*GR-Grant Number")
i = 1
for record in records:
    f.write(record.get('PMID', ""))
    f.write("*")
    f.write(record.get('TI', ""))
    f.write("*")
    f.write(str(record.get('AUID', "")))
    f.write("*")
    f.write(str(record.get('AU', "")))
    f.write("*") 
    f.write(str(record.get('AD', "")))
    f.write("*")
    f.write(str(record.get('AID', "")))
    f.write("*")
    f.write(str(record.get('GR', "")))
    f.write("*")
    f.write("\n")
    i = i+1

f.close()

print("Total records processed: " + str(i))
# Out:
# 21641
# Total records: 21641
# Total records processed: 10001

# %% [markdown]
# ####  use real expressions to search the AID field for 10.* [doi ]

# %%
f = open('OutputReportTest.txt')

while True:
	line = f.readline()
	if not line: break
	print(line)
f.close()
# Out:
# ['29682398', '29682382', '29681647', '29676225', '29673526', '29672601', '29671273', '29671268', '29671267', '29671266', '29671265', '29671264', '29670931', '29670925', '29670334', '29666723', '29664956', '29664904', '29662744', '29662743']
#
# 29682398
#
# Pubmed Record ID (PMID): 29682398
#
# Title: Nickel-Catalyzed Suzuki-Miyaura Coupling of Aliphatic Amides.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Boit TB', 'Weires NA', 'Kim J', 'Garg NK']
#
# Author affiliation (AD): Department of Chemistry and Biochemistry, University of California, Los Angeles, California 90095, United States. Department of Chemistry and Biochemistry, University of California, Los Angeles, California 90095, United States. Department of Chemistry and Biochemistry, University of California, Los Angeles, California 90095, United States. Department of Chemistry and Biochemistry, University of California, Los Angeles, California 90095, United States.
#
# Article Identifier/DOI (AID): ['10.1021/acscatal.7b03688 [doi]']
#
#
#
#
#
#
#
# 29682382
#
# Pubmed Record ID (PMID): 29682382
#
# Title: Paroxysmal Nocturnal Dyspnea Secondary to Right Ventricular Myxoma: A Novel Presentation of an Unusual Tumor.
#
# Author Identifier (AUID): ['ORCID: 0000-0002-7828-1522']
#
# Author(s)(AU): ['Knight TE', 'Shiramizu B', 'Ly P', 'Thompson KS', 'Reddy V']
#
# Author affiliation (AD): Division of Pediatric Hematology and Oncology, Department of Pediatrics, Children's Hospital of Michigan, Detroit, MI, USA. Division of Pediatric Hematology and Oncology, Department of Pediatrics, John A. Burns School of Medicine, University of Hawaii, Honolulu, HI, USA. Department of Pediatrics, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Department of Pathology, John A. Burns School of Medicine, University of Hawaii, Honolulu, HI, USA. Clinical Laboratories of Hawaii, Honolulu, HI, USA. Division of Pediatric Cardiology, Department of Pediatrics, John A. Burns School of Medicine, University of Hawaii, Honolulu, HI, USA.
#
# Article Identifier/DOI (AID): ['10.1155/2018/4791379 [doi]']
#
#
#
#
#
#
#
# 29681647
#
# Pubmed Record ID (PMID): 29681647
#
# Title: The multidimensional behavioural hypervolumes of two interacting species predict their space use and survival.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Lichtenstein JLL', 'Wright CM', 'McEwen B', 'Pinter-Wollman N', 'Pruitt JN']
#
# Author affiliation (AD): Department of Ecology, Evolution & Marine Biology, University of California Santa Barbara, Santa Barbara, CA, U.S.A. Department of Ecology, Evolution & Marine Biology, University of California Santa Barbara, Santa Barbara, CA, U.S.A. Department of Biological Sciences, University of Pittsburgh, Pittsburgh, PA, U.S.A. Department of Ecology and Evolutionary Biology, University of California Los Angeles, Los Angeles, CA, U.S.A. Department of Ecology, Evolution & Marine Biology, University of California Santa Barbara, Santa Barbara, CA, U.S.A.
#
# Article Identifier/DOI (AID): ['10.1016/j.anbehav.2017.08.010 [doi]']
#
#
#
#
#
#
#
# 29676225
#
# Pubmed Record ID (PMID): 29676225
#
# Title: Post-stroke social networks, depressive symptoms, and disability in Tanzania: A prospective study.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Saadi A', "Okeng'o K", 'Biseko MR', 'Shayo AF', 'Mmbando TN', 'Grundy SJ', 'Xu A', 'Parker RA', 'Wibecan L', 'Iyer G', 'Onesmo PM', 'Kapina BN', 'Regenhardt RW', 'Mateen FJ']
#
# Author affiliation (AD): 1 National Clinical Scholars Program, University of California Los Angeles, Los Angeles, CA, USA. 2 108089 Muhimbili National Hospital , Dar es Salaam, Tanzania. 2 108089 Muhimbili National Hospital , Dar es Salaam, Tanzania. 2 108089 Muhimbili National Hospital , Dar es Salaam, Tanzania. 2 108089 Muhimbili National Hospital , Dar es Salaam, Tanzania. 3 Department of Neurology, Massachusetts General Hospital, Boston, MA, USA. 4 Biostatistics Center, Massachusetts General Hospital, Boston, MA, USA. 4 Biostatistics Center, Massachusetts General Hospital, Boston, MA, USA. 5 Harvard Medical School, Boston, USA. 6 Massachusetts General Hospital, Boston, MA, USA. 7 Harvard T.H. Chan School of Public Health, Boston, MA, USA. 2 108089 Muhimbili National Hospital , Dar es Salaam, Tanzania. 2 108089 Muhimbili National Hospital , Dar es Salaam, Tanzania. 8 Partners Neurology Residency, Massachusetts General Hospital and Brigham and Women's Hospital, Boston, MA, USA. 5 Harvard Medical School, Boston, USA. 6 Massachusetts General Hospital, Boston, MA, USA.
#
# Article Identifier/DOI (AID): ['10.1177/1747493018772788 [doi]']
#
#
#
#
#
#
#
# 29673526
#
# Pubmed Record ID (PMID): 29673526
#
# Title: Genetic Reporters of Neuronal Activity: c-Fos and G-CaMP6.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Hudson AE']
#
# Author affiliation (AD): UCLA, Los Angeles, CA, United States. Electronic address: ahudson@mednet.ucla.edu.
#
# Article Identifier/DOI (AID): ['S0076-6879(18)30036-3 [pii]', '10.1016/bs.mie.2018.01.023 [doi]']
#
#
#
#
#
#
#
# 29672601
#
# Pubmed Record ID (PMID): 29672601
#
# Title: Expression of immune checkpoint regulators, cytotoxic T lymphocyte antigen 4 (CTLA-4) and programmed death-ligand 1 (PD-L1), in female breast carcinomas.
#
# Author Identifier (AUID): ['ORCID: http://orcid.org/0000-0002-9986-8058']
#
# Author(s)(AU): ['Kassardjian A', 'Shintaku PI', 'Moatamed NA']
#
# Author affiliation (AD): Department of Pathology and Laboratory Medicine, David Geffen School of Medicine at UCLA, Los Angeles, California, United States of America. Department of Pathology and Laboratory Medicine, David Geffen School of Medicine at UCLA, Los Angeles, California, United States of America. Department of Pathology and Laboratory Medicine, David Geffen School of Medicine at UCLA, Los Angeles, California, United States of America.
#
# Article Identifier/DOI (AID): ['10.1371/journal.pone.0195958 [doi]', 'PONE-D-18-05387 [pii]']
#
#
#
#
#
#
#
# 29671273
#
# Pubmed Record ID (PMID): 29671273
#
# Title: Intravital Imaging of Human Melanoma Cells in the Mouse Ear Skin by Two-Photon Excitation Microscopy.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Bentolila NY', 'Barnhill RL', 'Lugassy C', 'Bentolila LA']
#
# Author affiliation (AD): Genesis Innovation Lab, YULA School, Los Angeles, CA, USA. Department of Pathology, Institut Curie, University of Paris Rene Descartes, Paris, France. Department of Translational Research, Institut Curie, Paris, France. California NanoSystems Institute, University of California Los Angeles, Los Angeles, CA, USA. lbento@chem.ucla.edu. Department of Chemistry and Biochemistry, University of California Los Angeles, Los Angeles, CA, USA. lbento@chem.ucla.edu.
#
# Article Identifier/DOI (AID): ['10.1007/978-1-4939-7724-6_15 [doi]']
#
#
#
#
#
#
#
# 29671268
#
# Pubmed Record ID (PMID): 29671268
#
# Title: Using YFP as a Reporter of Gene Expression in the Green Alga Chlamydomonas reinhardtii.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Blaby-Haas CE', 'Page MD', 'Merchant SS']
#
# Author affiliation (AD): Department of Biology, Brookhaven National Laboratory, Upton, NY, USA. cblaby@bnl.gov. Department of Chemistry and Biochemistry, University of California Los Angeles, Los Angeles, CA, USA. Department of Chemistry and Biochemistry, University of California Los Angeles, Los Angeles, CA, USA. Institute for Genomics and Proteomics, University of California Los Angeles, Los Angeles, CA, USA.
#
# Article Identifier/DOI (AID): ['10.1007/978-1-4939-7724-6_10 [doi]']
#
#
#
#
#
#
#
# 29671267
#
# Pubmed Record ID (PMID): 29671267
#
# Title: Reporter Gene Assays Using Viral Functional Genomics Libraries.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Welch G', 'Damoiseaux R', 'Miraglia L']
#
# Author affiliation (AD): Department of Genomics, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. Functional Genomics Screening Team, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. Department of Molecular and Medical Pharmacology, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. California NanoSystems Institute, University of California Los Angeles, Los Angeles, CA, USA. Johnsson Comprehensive Cancer Center, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Department of Genomics, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. miraglia@gnf.org. Functional Genomics Screening Team, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. miraglia@gnf.org.
#
# Article Identifier/DOI (AID): ['10.1007/978-1-4939-7724-6_9 [doi]']
#
#
#
#
#
#
#
# 29671266
#
# Pubmed Record ID (PMID): 29671266
#
# Title: Reporter Gene Assays Using Transfectable Functional Genomics Libraries.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Welch G', 'Damoiseaux R', 'Miraglia L']
#
# Author affiliation (AD): Department of Genomics, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. Functional Genomics Screening Team, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. Department of Molecular and Medical Pharmacology, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. California NanoSystems Institute, University of California Los Angeles, Los Angeles, CA, USA. Johnsson Comprehensive Cancer Center, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Department of Genomics, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. miraglia@gnf.org. Functional Genomics Screening Team, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. miraglia@gnf.org.
#
# Article Identifier/DOI (AID): ['10.1007/978-1-4939-7724-6_8 [doi]']
#
#
#
#
#
#
#
# 29671265
#
# Pubmed Record ID (PMID): 29671265
#
# Title: Making It All Work: Functional Genomics and Reporter Gene Assays.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Welch G', 'Damoiseaux R', 'Miraglia L']
#
# Author affiliation (AD): Department of Genomics, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. Functional Genomics Screening Team, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. Department of Molecular and Medical Pharmacology, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. California NanoSystems Institute, University of California Los Angeles, Los Angeles, CA, USA. Johnsson Comprehensive Cancer Center, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Department of Genomics, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. miraglia@gnf.org. Functional Genomics Screening Team, The Genomics Institute of the Novartis Research Foundation, San Diego, CA, USA. miraglia@gnf.org.
#
# Article Identifier/DOI (AID): ['10.1007/978-1-4939-7724-6_7 [doi]']
#
#
#
#
#
#
#
# 29671264
#
# Pubmed Record ID (PMID): 29671264
#
# Title: High-Throughput Screening of a Luciferase Reporter of Gene Silencing on the Inactive X Chromosome.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Keegan A', 'Plath K', 'Damoiseaux R']
#
# Author affiliation (AD): Department of Biological Chemistry, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Johnsson Comprehensive Cancer Center, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Molecular Biology Institute, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Eli and Edythe Broad Center of Regenerative Medicine and Stem Cell Research, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Department of Biological Chemistry, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Johnsson Comprehensive Cancer Center, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Molecular Biology Institute, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Eli and Edythe Broad Center of Regenerative Medicine and Stem Cell Research, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. Johnsson Comprehensive Cancer Center, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. rdamoiseaux@mednet.ucla.edu. Department of Molecular and Medical Pharmacology, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, CA, USA. rdamoiseaux@mednet.ucla.edu. California NanoSystems Institute, University of California Los Angeles, Los Angeles, CA, USA. rdamoiseaux@mednet.ucla.edu.
#
# Article Identifier/DOI (AID): ['10.1007/978-1-4939-7724-6_6 [doi]']
#
#
#
#
#
#
#
# 29670931
#
# Pubmed Record ID (PMID): 29670931
#
# Title: EMERGEncy ID NET: Review of a 20-Year Multisite Emergency Department Emerging Infections Research Network.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Santibanez S', 'Fischer LS', 'Krishnadasan A', 'Sederdahl B', 'Merlin T', 'Moran GJ', 'Talan DA']
#
# Author affiliation (AD): Division of Preparedness and Emerging Infections, National Center for Emerging and Zoonotic Infectious Diseases, Centers for Disease Control and Prevention, Atlanta, Georgia. Rollins School of Public Health, Emory University, Atlanta, Georgia. Division of Preparedness and Emerging Infections, National Center for Emerging and Zoonotic Infectious Diseases, Centers for Disease Control and Prevention, Atlanta, Georgia. Department of Emergency Medicine, Olive View-UCLA Medical Center, Los Angeles, California. Rollins School of Public Health, Emory University, Atlanta, Georgia. Division of Preparedness and Emerging Infections, National Center for Emerging and Zoonotic Infectious Diseases, Centers for Disease Control and Prevention, Atlanta, Georgia. Department of Emergency Medicine, Olive View-UCLA Medical Center, Los Angeles, California. Department of Emergency Medicine, Olive View-UCLA Medical Center, Los Angeles, California.
#
# Article Identifier/DOI (AID): ['10.1093/ofid/ofx218 [doi]', 'ofx218 [pii]']
#
#
#
#
#
#
#
# 29670925
#
# Pubmed Record ID (PMID): 29670925
#
# Title: Pseudocirrhosis in a Patient with New-Onset Dysphagia and History of Ovarian Carcinoma.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Zanazanian A', 'Kalani A', 'Tabibian JH']
#
# Author affiliation (AD): Division of Gastroenterology, Olive View-UCLA Medical Center, Sylmar, CA. Division of Digestive Diseases, University of California-Los Angeles, Los Angeles, CA. Division of Gastroenterology, Olive View-UCLA Medical Center, Sylmar, CA. Division of Gastroenterology, University of Pennsylvania, Philadelphia, PA.
#
# Article Identifier/DOI (AID): ['10.14309/crj.2018.29 [doi]', 'crj.2018.29 [pii]']
#
#
#
#
#
#
#
# 29670334
#
# Pubmed Record ID (PMID): 29670334
#
# Title: Aldoxorubicin: a tumor-targeted doxorubicin conjugate for relapsed or refractory soft tissue sarcomas.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Gong J', 'Yan J', 'Forscher C', 'Hendifar A']
#
# Author affiliation (AD): Department of Medical Oncology, City of Hope National Medical Center, Duarte, CA, USA. Department of Hematology and Oncology, Harbor-UCLA Medical Center, Torrance, CA, USA. Sarcoma Program, Samuel Oschin Cancer Center, Cedars-Sinai Medical Center, Los Angeles, CA, USA. Gastrointestinal and Neuroendocrine Malignancies, Samuel Oschin Cancer Center, Cedars-Sinai Medical Center, Los Angeles, CA, USA.
#
# Article Identifier/DOI (AID): ['10.2147/DDDT.S140638 [doi]', 'dddt-12-777 [pii]']
#
#
#
#
#
#
#
# 29666723
#
# Pubmed Record ID (PMID): 29666723
#
# Title: A Challenging Case of Severe Ulcerative Colitis following the Initiation of Secukinumab for Ankylosing Spondylitis.
#
# Author Identifier (AUID): ['ORCID: 0000-0001-9606-8429', 'ORCID: 0000-0003-2549-9939']
#
# Author(s)(AU): ['Ehrlich D', 'Jamaluddin N', 'Pisegna J', 'Padua D']
#
# Author affiliation (AD): Division of Digestive Diseases, Department of Medicine, David Geffen School of Medicine at UCLA, Los Angeles, CA, USA. Division of Digestive Diseases, Department of Medicine, David Geffen School of Medicine at UCLA, Los Angeles, CA, USA. Division of Digestive Diseases, Department of Medicine, David Geffen School of Medicine at UCLA, Los Angeles, CA, USA. Division of Gastroenterology, Hepatology and Parenteral Nutrition, VA Greater Los Angeles Healthcare System, Los Angeles, CA, USA. Division of Digestive Diseases, Department of Medicine, David Geffen School of Medicine at UCLA, Los Angeles, CA, USA. Division of Gastroenterology, Hepatology and Parenteral Nutrition, VA Greater Los Angeles Healthcare System, Los Angeles, CA, USA.
#
# Article Identifier/DOI (AID): ['10.1155/2018/9679287 [doi]']
#
#
#
#
#
#
#
# 29664956
#
# Pubmed Record ID (PMID): 29664956
#
# Title: You pray to your God: A qualitative analysis of challenges in the provision of safe, timely, and affordable surgical care in Uganda.
#
# Author Identifier (AUID): ['ORCID: http://orcid.org/0000-0003-1735-7316', 'ORCID: http://orcid.org/0000-0002-3546-9867']
#
# Author(s)(AU): ['Albutt K', 'Yorlets RR', 'Punchak M', 'Kayima P', 'Namanya DB', 'Anderson GA', 'Shrime MG']
#
# Author affiliation (AD): Program in Global Surgery and Social Change (PGSSC), Harvard Medical School, Boston, Massachusetts, United States of America. Department of Surgery, Massachusetts General Hospital (MGH), Boston, Massachusetts, United States of America. Program in Global Surgery and Social Change (PGSSC), Harvard Medical School, Boston, Massachusetts, United States of America. Program in Global Surgery and Social Change (PGSSC), Harvard Medical School, Boston, Massachusetts, United States of America. David Geffen School of Medicine at UCLA, Los Angeles, California, United States of America. Mbarara University of Science and Technology (MUST), Mbarara, Uganda. Ministry of Health (MOH), Kampala, Uganda. Uganda Martyrs University (UMU), Nkozi, Uganda. Program in Global Surgery and Social Change (PGSSC), Harvard Medical School, Boston, Massachusetts, United States of America. Department of Surgery, Massachusetts General Hospital (MGH), Boston, Massachusetts, United States of America. Program in Global Surgery and Social Change (PGSSC), Harvard Medical School, Boston, Massachusetts, United States of America. Department of Otolaryngology, Massachusetts Eye and Ear Infirmary (MEEI), Boston, Massachusetts, United States of America.
#
# Article Identifier/DOI (AID): ['10.1371/journal.pone.0195986 [doi]', 'PONE-D-17-33078 [pii]']
#
#
#
#
#
#
#
# 29664904
#
# Pubmed Record ID (PMID): 29664904
#
# Title: Surprisal analysis of genome-wide transcript profiling identifies differentially expressed genes and pathways associated with four growth conditions in the microalga Chlamydomonas.
#
# Author Identifier (AUID): ['ORCID: http://orcid.org/0000-0002-5016-9547']
#
# Author(s)(AU): ['Bogaert KA', 'Manoharan-Basil SS', 'Perez E', 'Levine RD', 'Remacle F', 'Remacle C']
#
# Author affiliation (AD): Theoretical Physical Chemistry, UR MOLSYS, University of Liege, Liege, Belgium. Genetics and Physiology of Microalgae, UR InBios, University of Liege, Liege, Belgium. Genetics and Physiology of Microalgae, UR InBios, University of Liege, Liege, Belgium. The Fritz Haber Research Center for Molecular Dynamics, Institute of Chemistry, Hebrew University of Jerusalem, Jerusalem, Israel. Department of Molecular and Medical Pharmacology, David Geffen School of Medicine, University of California Los Angeles, Los Angeles, California, United States of America. Theoretical Physical Chemistry, UR MOLSYS, University of Liege, Liege, Belgium. Genetics and Physiology of Microalgae, UR InBios, University of Liege, Liege, Belgium.
#
# Article Identifier/DOI (AID): ['10.1371/journal.pone.0195142 [doi]', 'PONE-D-17-37946 [pii]']
#
#
#
#
#
#
#
# 29662744
#
# Pubmed Record ID (PMID): 29662744
#
# Title: Postoperative Complications Associated With rhBMP2 Use in Posterior/Posterolateral Lumbar Fusion.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Esmail N', 'Buser Z', 'Cohen JR', 'Brodke DS', 'Meisel HJ', 'Park JB', 'Youssef JA', 'Wang JC', 'Yoon ST']
#
# Author affiliation (AD): University of Southern California, Los Angeles, CA, USA. University of Southern California, Los Angeles, CA, USA. University of California-Los Angeles, Los Angeles, CA, USA. University of Utah School of Medicine, Salt Lake City, UT, USA. Bergmannstrost Hospital, Halle, Germany. Uijongbu St. Mary's Hospital, The Catholic University of Korea School of Medicine, Uijongbu, Korea. Spine Colorado Durango, Durango, CO, USA. University of Southern California, Los Angeles, CA, USA. Emory Spine Center, Atlanta, GA, USA.
#
# Article Identifier/DOI (AID): ['10.1177/2192568217698141 [doi]', '10.1177_2192568217698141 [pii]']
#
#
#
#
#
#
#
# 29662743
#
# Pubmed Record ID (PMID): 29662743
#
# Title: Trends Analysis of rhBMP2 Utilization in Single-Level Anterior Lumbar Interbody Fusion in the United States.
#
# Author Identifier (AUID):
#
# Author(s)(AU): ['Lao L', 'Cohen JR', 'Buser Z', 'Brodke DS', 'Yoon ST', 'Youssef JA', 'Park JB', 'Meisel HJ', 'Wang JC']
#
# Author affiliation (AD): University of Southern California, Los Angeles, CA, USA. Renji Hospital, Shanghai Jiao Tong University, Shanghai, China. University of California at Los Angeles, Los Angeles, CA, USA. University of Southern California, Los Angeles, CA, USA. University of Utah, Salt Lake City, UT, USA. Emory Spine Center, Atlanta, GA, USA. Spine Colorado, Durango, CO, USA. Uijongbu St. Mary's Hospital, The Catholic University of Korea, Uijongbu, Korea. Bergmannstrost Hospital, Halle, Germany. University of Southern California, Los Angeles, CA, USA.
#
# Article Identifier/DOI (AID): ['10.1177/2192568217701119 [doi]', '10.1177_2192568217701119 [pii]']
